# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DYPEF\Desktop\dsbdall\HospInfo.csv\HospInfo.csv')

# %%
df
# Out:
#       Provider ID                       Hospital Name  \
# 0           10005       MARSHALL MEDICAL CENTER SOUTH
# 1           10012      DEKALB REGIONAL MEDICAL CENTER
# 2           10032                    WEDOWEE HOSPITAL
# 3           10095                HALE COUNTY HOSPITAL
# 4           10131            CRESTWOOD MEDICAL CENTER
# ...           ...                                 ...
# 4807       450617  CLEAR LAKE REGIONAL MEDICAL CENTER
# 4808       520194   ORTHOPAEDIC HOSPITAL OF WISCONSIN
# 4809       491302   CARILION GILES COMMUNITY HOSPITAL
# 4810       510012            PLEASANT VALLEY HOSPITAL
# 4811       490053          JOHNSTON MEMORIAL HOSPITAL
#
#                             Address            City State  ZIP Code  \
# 0        2505 U S HIGHWAY 431 NORTH            BOAZ    AL     35957
# 1              200 MED CENTER DRIVE      FORT PAYNE    AL     35968
# 2             209 NORTH MAIN STREET         WEDOWEE    AL     36278
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 29 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Provider ID                                                    4812 non-null   int64
#  1   Hospital Name                                                  4812 non-null   object
#  2   Address                                                        4812 non-null   object
#  3   City                                                           4812 non-null   object
#  4   State                                                          4812 non-null   object
#  5   ZIP Code                                                       4812 non-null   int64
#  6   County Name                                                    4797 non-null   object
# ...

# %%
z=df[['Provider ID','ZIP Code', 'Phone Number', 'Emergency Services']]

# %%
df['Provider ID']
# Out:
# 0        10005
# 1        10012
# 2        10032
# 3        10095
# 4        10131
#          ...
# 4807    450617
# 4808    520194
# 4809    491302
# 4810    510012
# 4811    490053
# Name: Provider ID, Length: 4812, dtype: int64

# %%
z
# Out:
#       Provider ID  ZIP Code  Phone Number  Emergency Services
# 0           10005     35957    2565938310                True
# 1           10012     35968    2568453150                True
# 2           10032     36278    2563572111                True
# 3           10095     36744    3346243024                True
# 4           10131     35801    2568823100                True
# ...           ...       ...           ...                 ...
# 4807       450617     77598    2813322511                True
# 4808       520194     53212    4149616800               False
# 4809       491302     24134    5409216000                True
# 4810       510012     25550    3046754340                True
# 4811       490053     24211    2762581000                True
#
# [4812 rows x 4 columns]

# %%
df['Provider ID'].min()
# Out:
# 10001

# %%
df['Provider ID'].max()
# Out:
# 670118

# %%
df['Provider ID'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4807    True
# 4808    True
# 4809    True
# 4810    True
# 4811    True
# Name: Provider ID, Length: 4812, dtype: bool

# %%
x=pd.notnull(['Emergency Services'])

# %%
x
# Out:
# array([ True])

# %%
from sklearn import preprocessing

# %%
y=df.fillna(df['Provider ID'].min())

# %%
y
# Out:
#       Provider ID                       Hospital Name  \
# 0           10005       MARSHALL MEDICAL CENTER SOUTH
# 1           10012      DEKALB REGIONAL MEDICAL CENTER
# 2           10032                    WEDOWEE HOSPITAL
# 3           10095                HALE COUNTY HOSPITAL
# 4           10131            CRESTWOOD MEDICAL CENTER
# ...           ...                                 ...
# 4807       450617  CLEAR LAKE REGIONAL MEDICAL CENTER
# 4808       520194   ORTHOPAEDIC HOSPITAL OF WISCONSIN
# 4809       491302   CARILION GILES COMMUNITY HOSPITAL
# 4810       510012            PLEASANT VALLEY HOSPITAL
# 4811       490053          JOHNSTON MEMORIAL HOSPITAL
#
#                             Address            City State  ZIP Code  \
# 0        2505 U S HIGHWAY 431 NORTH            BOAZ    AL     35957
# 1              200 MED CENTER DRIVE      FORT PAYNE    AL     35968
# 2             209 NORTH MAIN STREET         WEDOWEE    AL     36278
# ...

# %%
scaler = preprocessing.MinMaxScaler()

# %%
x=scaler.fit_transform(z)

# %%
x
# Out:
# array([[6.05953187e-06, 3.55939029e-01, 1.81767776e-01, 1.00000000e+00],
#        [1.66637126e-05, 3.56049775e-01, 1.82048387e-01, 1.00000000e+00],
#        [4.69613720e-05, 3.59170811e-01, 1.81503750e-01, 1.00000000e+00],
#        ...,
#        [7.29114687e-01, 2.36906752e-01, 4.99026734e-01, 1.00000000e+00],
#        [7.57458148e-01, 2.51162838e-01, 2.35418248e-01, 1.00000000e+00],
#        [7.27222598e-01, 2.37681977e-01, 2.03709584e-01, 1.00000000e+00]])

# %%
frame=pd.DataFrame(x, columns=['Provider ID','ZIP Code', 'Phone Number', 'Emergency Services'])

# %%
frame
# Out:
#       Provider ID  ZIP Code  Phone Number  Emergency Services
# 0        0.000006  0.355939      0.181768                 1.0
# 1        0.000017  0.356050      0.182048                 1.0
# 2        0.000047  0.359171      0.181504                 1.0
# 3        0.000142  0.363862      0.268836                 1.0
# 4        0.000197  0.354368      0.182090                 1.0
# ...           ...       ...           ...                 ...
# 4807     0.667482  0.775175      0.209371                 1.0
# 4808     0.772883  0.529660      0.358478                 0.0
# 4809     0.729115  0.236907      0.499027                 1.0
# 4810     0.757458  0.251163      0.235418                 1.0
# 4811     0.727223  0.237682      0.203710                 1.0
#
# [4812 rows x 4 columns]
